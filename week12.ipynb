# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAdhikaIsaNugraha/PVCK_Ganjil_2023/blob/main/week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MODUL 12 – Histogram, Histogram Equalization, Dithering**
#
# ---

# %% [markdown]
# > Muhammad Adhika Isa Nugraha
#
# > 12/2141720267
#
# > TI-3I
#
# ---

# %% [markdown]
# # **D. Tugas Praktikum**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/haarcascades/haarcascade_frontalface_alt.xml')

jokowi = cv.imread('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/jokowi.jpg',0)
roi_wajah = cascade_wajah.detectMultiScale(jokowi)
for(x,y,w,h) in roi_wajah:
  cv.rectangle(jokowi,(x,y),(x+w,y+h),(255,255,255),3)
plt.figure(figsize = (4,4))
plt.imshow(jokowi, cmap='gray')

# %%
#Jokowi

# Load the face cascade
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/haarcascades/haarcascade_frontalface_alt.xml')

# Load the image in color mode
jokowi = cv.imread('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/jokowi.jpg', cv.IMREAD_COLOR)

# Convert BGR to RGB
jokowi_rgb = cv.cvtColor(jokowi, cv.COLOR_BGR2RGB)

# Detect faces in the image
roi_wajah = cascade_wajah.detectMultiScale(jokowi_rgb)

# Draw rectangles around the faces
for (x, y, w, h) in roi_wajah:
    cv.rectangle(jokowi_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Display the image with rectangles
plt.figure(figsize=(4, 4))
plt.imshow(jokowi_rgb)

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Load the face cascade
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/haarcascades/haarcascade_frontalface_alt.xml')

# List of image paths
image_paths = [
    '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/jokowi.jpg',
    '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/kartini.jpg',
    '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/kucing.jpg',
    '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/mjordan.jpg',
    '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/solvayconf.jpg',
    # Add more image paths as needed
]

# Loop through each image
for image_path in image_paths:
    print(f'Processing image: {image_path}')

    # Load the image in color mode
    img = cv.imread(image_path, cv.IMREAD_COLOR)

    # Check if the image is loaded successfully
    if img is None:
        print(f'Error loading image: {image_path}')
        continue

    # Convert BGR to RGB
    img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

    # Detect faces in the image
    roi_wajah = cascade_wajah.detectMultiScale(img_rgb)

    # Draw green rectangles around the faces
    for (x, y, w, h) in roi_wajah:
        cv.rectangle(img_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

    # Display the image with green rectangles
    plt.figure(figsize=(3, 3))
    plt.imshow(img_rgb)
    plt.title(f'Detected Faces in {image_path}')
    plt.show()
# Out:
# Processing image: /content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/jokowi.jpg
# Processing image: /content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/kartini.jpg
# Processing image: /content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/kucing.jpg
# Processing image: /content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/mjordan.jpg
# Processing image: /content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/solvayconf.jpg

# %%
#Jokowi

# Load the face cascade
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/haarcascades/haarcascade_eye.xml')

# Load the image in color mode
jokowi = cv.imread('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/jokowi.jpg', cv.IMREAD_COLOR)

# Convert BGR to RGB
jokowi_rgb = cv.cvtColor(jokowi, cv.COLOR_BGR2RGB)

# Detect faces in the image
roi_wajah = cascade_wajah.detectMultiScale(jokowi_rgb)

# Draw rectangles around the faces
for (x, y, w, h) in roi_wajah:
    cv.rectangle(jokowi_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Display the image with rectangles
plt.figure(figsize=(4, 4))
plt.imshow(jokowi_rgb)

# %% [markdown]
# > 6. Blur the detected part of the face. Here's an example of the output. Hint: you can use
# cv.medianBlur to give a blur effect.

# %%
import cv2
from matplotlib import pyplot as plt

# Load the face cascade
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/haarcascades/haarcascade_frontalface_alt.xml')

# Load the image in color mode
jokowi = cv2.imread('/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 12/facedet/mjordan.jpg', cv2.IMREAD_COLOR)

# Convert BGR to RGB
jokowi_rgb = cv2.cvtColor(jokowi, cv2.COLOR_BGR2RGB)

# Convert the image to grayscale
jokowi_gray = cv2.cvtColor(jokowi_rgb, cv2.COLOR_RGB2GRAY)

# Detect faces in the image
roi_wajah = cascade_wajah.detectMultiScale(jokowi_gray)

# Blur each detected face
for (x, y, w, h) in roi_wajah:
    face_roi = jokowi_gray[y:y+h, x:x+w]
    blurred_face = cv2.medianBlur(face_roi, 15)
    jokowi_gray[y:y+h, x:x+w] = blurred_face

# Display the image with rectangles in grayscale
plt.figure(figsize=(4, 4))
plt.imshow(jokowi_gray, cmap='gray')
plt.axis('off')
plt.show()
