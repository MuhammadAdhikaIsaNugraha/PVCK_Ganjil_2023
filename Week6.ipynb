# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAdhikaIsaNugraha/PVCK_Ganjil_2023/blob/main/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MODUL 6 – Histogram, Histogram Equalization, Dithering**
#
# ---

# %% [markdown]
# > Muhammad Adhika Isa Nugraha
#
# > 12/2141720267
#
# > TI-3I
#
# ---

# %% [markdown]
# # **Tugas Praktikum**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import math
import os
import glob

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np

# Load an image
image_path = '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 6/lena.jpg'  # Replace with the path to your image
image = cv.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Unable to load the image.")
else:
    # Split the image into RGB channels
    b, g, r = cv.split(image)

    # Calculate histograms for each channel
    hist_r = cv.calcHist([r], [0], None, [256], [0, 256])
    hist_b = cv.calcHist([b], [0], None, [256], [0, 256])
    hist_g = cv.calcHist([g], [0], None, [256], [0, 256])


    # Plot the histograms
    plt.figure(figsize=(12, 4))

    plt.subplot(131)
    plt.plot(hist_b, color='blue')
    plt.title('Blue Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.subplot(132)
    plt.plot(hist_g, color='green')
    plt.title('Green Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.subplot(133)
    plt.plot(hist_r, color='red')
    plt.title('Red Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.tight_layout()
    plt.show()

# End of the program

# %% [markdown]
# **3. Make an image histogram like the following histogram output based on the flowchart below : (Use image lena.jpg)**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np

# Load an image
image_path = '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 6/lena.jpg'  # Replace with the path to your image
image = cv.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Unable to load the image.")
else:
    # Split the image into RGB channels
    b, g, r = cv.split(image)

    # Calculate histograms for each channel
    hist_r = cv.calcHist([r], [0], None, [256], [0, 256])
    hist_g = cv.calcHist([g], [0], None, [256], [0, 256])
    hist_b = cv.calcHist([b], [0], None, [256], [0, 256])

    # Plot the histograms
    plt.figure(figsize=(12, 4))

    plt.subplot(131)
    plt.plot(hist_r, color='red')
    plt.title('Red Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.subplot(132)
    plt.plot(hist_g, color='green')
    plt.title('Green Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.subplot(133)
    plt.plot(hist_b, color='blue')
    plt.title('Blue Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.tight_layout()
    plt.show()

# End of the program

# %% [markdown]
# **4. After working on question no. 3, make the same image histogram but use the library that is owned by NumPy, namely " histogram ". Compare the results. Does the output appear the same?**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np

# Load an image
image_path = '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 6/lena.jpg'  # Replace with the path to your image
image = cv.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Unable to load the image.")
else:
    # Split the image into RGB channels
    b, g, r = cv.split(image)

    # Calculate histograms for each channel using OpenCV
    hist_r = cv.calcHist([r], [0], None, [256], [0, 256])
    hist_g = cv.calcHist([g], [0], None, [256], [0, 256])
    hist_b = cv.calcHist([b], [0], None, [256], [0, 256])

    # Calculate histograms for each channel using NumPy
    hist_r_np, _ = np.histogram(r, bins=256, range=(0, 256))
    hist_g_np, _ = np.histogram(g, bins=256, range=(0, 256))
    hist_b_np, _ = np.histogram(b, bins=256, range=(0, 256))

    # Plot histograms generated by OpenCV
    plt.figure(figsize=(12, 4))

    plt.subplot(231)
    plt.plot(hist_r, color='red')
    plt.title('OpenCV Red Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.subplot(232)
    plt.plot(hist_g, color='green')
    plt.title('OpenCV Green Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.subplot(233)
    plt.plot(hist_b, color='blue')
    plt.title('OpenCV Blue Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    # Plot histograms generated by NumPy
    plt.subplot(234)
    plt.plot(hist_r_np, color='red')
    plt.title('NumPy Red Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.subplot(235)
    plt.plot(hist_g_np, color='green')
    plt.title('NumPy Green Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.subplot(236)
    plt.plot(hist_b_np, color='blue')
    plt.title('NumPy Blue Histogram')
    plt.xlabel('Intensitas Warna')
    plt.ylabel('Jumlah Kemunculan')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **5. Make an image histogram such as the output equalization histogram and also the image display before and after the following equalization histogram process based on the flowchart below : (Use image lena_lc .jpg)**

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Load an image
image_path = '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 6/lena_lc.jpg'  # Replace with the path to your image
image = cv.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Unable to load the image.")
else:
    # Split the image into RGB channels
    b, g, r = cv.split(image)

    # Apply histogram equalization to each channel
    equalized_r = cv.equalizeHist(r)
    equalized_g = cv.equalizeHist(g)
    equalized_b = cv.equalizeHist(b)

    # Merge the equalized channels to create the equalized color image
    equalized_image = cv.merge([equalized_b, equalized_g, equalized_r])

    # Plot the original and equalized images
    plt.figure(figsize=(12, 6))

    # Original Image
    plt.subplot(1, 2, 1)
    plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    # Equalized Image
    plt.subplot(1, 2, 2)
    plt.imshow(cv.cvtColor(equalized_image, cv.COLOR_BGR2RGB))
    plt.title('Equalized Image')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

    # Plot histograms for each RGB channel
    plt.figure(figsize=(12, 4))

    # Original Image Histograms
    plt.subplot(131)
    plt.hist(r.ravel(), bins=256, range=(0, 256), color='red', alpha=0.6)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Red Channel Histogram (Original)')

    plt.subplot(132)
    plt.hist(g.ravel(), bins=256, range=(0, 256), color='green', alpha=0.6)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Green Channel Histogram (Original)')

    plt.subplot(133)
    plt.hist(b.ravel(), bins=256, range=(0, 256), color='blue', alpha=0.6)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Blue Channel Histogram (Original)')

    plt.tight_layout()
    plt.show()

    # Plot histograms for each RGB channel after equalization
    plt.figure(figsize=(12, 4))

    plt.subplot(131)
    plt.hist(equalized_r.ravel(), bins=256, range=(0, 256), color='red', alpha=0.6)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Red Channel Histogram (Equalized)')

    plt.subplot(132)
    plt.hist(equalized_g.ravel(), bins=256, range=(0, 256), color='green', alpha=0.6)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Green Channel Histogram (Equalized)')

    plt.subplot(133)
    plt.hist(equalized_b.ravel(), bins=256, range=(0, 256), color='blue', alpha=0.6)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Blue Channel Histogram (Equalized)')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **6. After working on question no. 5, make the same image histogram but use the library owned by CV2, namely " equalizeHist ". Compare the results. Does the output appear the same?**

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Load an image
image_path = '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 6/lena_lc.jpg'  # Replace with the path to your image
image = cv.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Unable to load the image.")
else:
    # Convert the image to grayscale for equalization
    grayscale_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

    # Apply histogram equalization to the grayscale image
    equalized_image = cv.equalizeHist(grayscale_image)

    # Plot the original and equalized images
    plt.figure(figsize=(12, 6))

    # Original Image
    plt.subplot(1, 2, 1)
    plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    # Equalized Image
    plt.subplot(1, 2, 2)
    plt.imshow(equalized_image, cmap='gray')
    plt.title('Equalized Image')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

    # Plot histograms for the original and equalized grayscale image
    plt.figure(figsize=(12, 4))

    # Original Grayscale Image Histogram
    plt.subplot(121)
    plt.hist(grayscale_image.ravel(), bins=256, range=(0, 256), color='gray', alpha=0.6)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Grayscale Histogram (Original)')

    # Equalized Grayscale Image Histogram
    plt.subplot(122)
    plt.hist(equalized_image.ravel(), bins=256, range=(0, 256), color='gray', alpha=0.6)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Grayscale Histogram (Equalized)')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **7. Do the mapping process of 16 million RGB colors into just 8 colors, namely black, green, yellow, blue, cyan, magenta, white as shown in the following output based on the flowchart below! (Use the image testlena .jpg)**

# %%
import cv2 as cv
import numpy as np
from sklearn.cluster import KMeans

# Load the original image
image_path = '/content/drive/MyDrive/Polinema/Semester 5/PVCK/Meeting 6/lena_lc.jpg'  # Replace with the path to your image
image = cv.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Unable to load the image.")
else:
    # Reshape the image to a 2D array of pixels
    pixels = image.reshape((-1, 3))

    # Define the number of clusters (in this case, 8 colors)
    num_clusters = 8

    # Perform k-means clustering
    kmeans = KMeans(n_clusters=num_clusters)
    kmeans.fit(pixels)

    # Define the 8 specific colors
    color_map = np.array([
        [0, 0, 0],      # Black
        [0, 255, 0],    # Green
        [255, 255, 0],  # Yellow
        [0, 0, 255],    # Blue
        [0, 255, 255],  # Cyan
        [255, 0, 255],  # Magenta
        [255, 255, 255],# White
        [128, 128, 128] # Gray
    ], dtype=int)

    # Replace each pixel with its corresponding cluster center color
    new_pixels = color_map[kmeans.labels_]

    # Reshape the new pixels back to the original image shape
    quantized_image = new_pixels.reshape(image.shape)

    # Display the original and quantized images
    cv.imshow('Original Image', image)
    cv.imshow('Quantized Image', quantized_image)
    cv.waitKey(0)
    cv.destroyAllWindows()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-1b0af907081a> in <cell line: 10>()
#      36
#      37     # Replace each pixel with its corresponding cluster center color
# ---> 38     new_pixels = color_map[kmeans.labels_]
#      39
#      40     # Reshape the new pixels back to the original image shape
#
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %% [markdown]
# **8. Do the Floyd and Steinberg dithering process like the following output (initial image display, and after dithering display) based on the flowchart below! (Use wiki.jpg image)**
